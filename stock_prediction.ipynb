# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\user\\Desktop\\CAPSTONE PROJECT\\ADANIENT.csv")
df
# Out:
#          Price              Close               High                Low  \
# 0       Ticker        ADANIENT.NS        ADANIENT.NS        ADANIENT.NS
# 1         Date                NaN                NaN                NaN
# 2   2026-04-21             2226.0             2255.0             2220.0
# 3   2026-04-22  2260.800048828125   2278.60009765625   2224.10009765625
# 4   2026-04-23             2300.0   2333.89990234375  2221.800048828125
# 5   2026-04-24   2287.60009765625   2321.39990234375             2227.0
# 6   2026-04-27  2321.800048828125             2337.0             2286.0
# 7   2026-04-28   2412.39990234375             2420.0   2320.89990234375
# 8   2026-04-29   2425.89990234375  2443.800048828125             2388.0
# 9   2026-04-30   2408.39990234375             2420.0  2328.800048828125
# 10  2026-05-01   2408.39990234375   2408.39990234375   2408.39990234375
# 11  2026-05-04  2485.699951171875             2515.0             2375.0
# ...

# %%
df = df[pd.to_numeric(df['Close'], errors='coerce').notna()]

# %%
for col in ['Open', 'High', 'Low', 'Close', 'Volume']:
    df[col] = pd.to_numeric(df[col], errors='coerce')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3776\2160277205.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
df = df.dropna()

# %%
df.head()
# Out:
#         Price        Close         High          Low         Open   Volume
# 2  2026-04-21  2226.000000  2255.000000  2220.000000  2229.699951  1818221
# 3  2026-04-22  2260.800049  2278.600098  2224.100098  2229.000000  3517237
# 4  2026-04-23  2300.000000  2333.899902  2221.800049  2243.500000  2948009
# 5  2026-04-24  2287.600098  2321.399902  2227.000000  2310.199951  2271317
# 6  2026-04-27  2321.800049  2337.000000  2286.000000  2300.199951  1500864

# %%
X = df[['Open', 'High', 'Low', 'Volume']]
y = df['Close']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=5)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor()
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, pred)
# Out:
# 0.8286588512047289

# %%
import joblib
joblib.dump(model, "stock_model.pkl")
# Out:
# ['stock_model.pkl']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(y_test.values[:50], label="Actual")
plt.plot(pred[:50], label="Predicted")
plt.legend()
plt.title("Stock Prediction Result")
plt.show()

# %%
import numpy as np
df_test = X_test.copy()
df_test["Predicted"] = pred
df_test["Signal"] = np.where(df_test["Predicted"] > df_test["Open"], "BUY", "SELL")
print(df_test.head())
# Out:
#            Open         High          Low   Volume    Predicted Signal
# 21  2700.000000  2710.000000  2647.500000  2033884  2673.552058   SELL
# 4   2243.500000  2333.899902  2221.800049  2948009  2270.562034    BUY
# 20  2781.100098  2803.100098  2661.000000  6742083  2673.995071   SELL
# 19  2530.100098  2720.000000  2530.000000  9539233  2579.314021    BUY
# 22  2734.699951  2774.500000  2697.000000  4204144  2674.787065   SELL

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_absolute_error(y_test, pred)
# Out:
# 54.29794042968742

# %%
mean_squared_error(y_test, pred)
# Out:
# 4652.306326706666
